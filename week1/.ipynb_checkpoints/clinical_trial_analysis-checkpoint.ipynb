# %%
import pandas as pd

df = pd.read_csv("trials.csv")
df.head()
# Out:
#     NCT Number                                        Study Title  \
# 0  NCT01109095  CMV-specific Cytotoxic T Lymphocytes Expressin...
# 1  NCT07066995  Mesothelin and Claudin 18.2 Dual-Target CAR-T ...
# 2  NCT03417895  SHR-1210 Combined With Apatinib in Treatment o...
# 3  NCT01452477            Tanshinone in Polycystic Ovary Syndrome
# 4  NCT05464875  A Multicenter Study of Avapritinib Efficacy an...
#
#                                       Study URL      Acronym Study Status  \
# 0  https://clinicaltrials.gov/study/NCT01109095     HERT-GBM    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT07066995  BAH2573-102   RECRUITING
# 2  https://clinicaltrials.gov/study/NCT03417895      PASSION    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT01452477          NaN      UNKNOWN
# 4  https://clinicaltrials.gov/study/NCT05464875          NaN   RECRUITING
#
#                                        Brief Summary Study Results  \
# ...

# %%
df["Study Status"].value_counts()
# Out:
# Study Status
# COMPLETED                7
# UNKNOWN                  5
# RECRUITING               3
# NOT_YET_RECRUITING       2
# ACTIVE_NOT_RECRUITING    2
# TERMINATED               1
# Name: count, dtype: int64

# %%
df["Phases"].value_counts()
# Out:
# Phases
# PHASE2           5
# PHASE1|PHASE2    3
# PHASE2|PHASE3    2
# PHASE1           1
# PHASE3           1
# EARLY_PHASE1     1
# Name: count, dtype: int64

# %%
df["Funder Type"].value_counts()
# Out:
# Funder Type
# OTHER       15
# INDUSTRY     5
# Name: count, dtype: int64

# %%
df["Study Status"].value_counts().plot(kind="bar")
import matplotlib.pyplot as plt

df["Study Status"].value_counts().plot(kind="bar")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
